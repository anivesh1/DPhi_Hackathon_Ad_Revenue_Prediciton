# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1st Attempt

# %%
df = pd.read_csv("/content/drive/MyDrive/SUMMER ANALYTICS IITG/Hackathon/Train_Data.csv")

# %%
df.head(46)

# %%
df.describe()
# Out:
#        impressions       clicks         cost  conversions       revenue
# count  4571.000000  4571.000000  4571.000000  4571.000000   4571.000000
# mean     92.635747    43.340844     2.800834     1.339094    231.865340
# std     198.349737   100.164913    14.361618     5.223922   1091.742763
# min       1.000000     0.000000     0.000000     0.000000      0.000000
# 25%       6.000000     2.000000     0.040000     0.000000      0.000000
# 50%      16.000000     7.000000     0.210000     0.000000      0.000000
# 75%      84.000000    38.000000     1.350000     1.000000     92.600000
# max    3239.000000  1771.000000   531.250000    94.000000  20515.410000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4571 entries, 0 to 4570
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         4571 non-null   object
#  1   campaign     4571 non-null   object
#  2   adgroup      4571 non-null   object
#  3   ad           4571 non-null   object
#  4   impressions  4571 non-null   int64
#  5   clicks       4571 non-null   int64
#  6   cost         4571 non-null   float64
#  7   conversions  4571 non-null   int64
#  8   revenue      4571 non-null   float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 321.5+ KB

# %%
sns.histplot(x = 'adgroup' , y = 'revenue',  data = df)

# %%
np.unique(df['ad'])
# Out:
# array(['ad 1', 'ad 10', 'ad 11', 'ad 12', 'ad 13', 'ad 14', 'ad 15',
#        'ad 16', 'ad 17', 'ad 18', 'ad 19', 'ad 2', 'ad 20', 'ad 21',
#        'ad 22', 'ad 23', 'ad 24', 'ad 25', 'ad 26', 'ad 27', 'ad 28',
#        'ad 29', 'ad 3', 'ad 30', 'ad 31', 'ad 32', 'ad 33', 'ad 34',
#        'ad 35', 'ad 36', 'ad 37', 'ad 38', 'ad 39', 'ad 4', 'ad 40',
#        'ad 41', 'ad 42', 'ad 43', 'ad 44', 'ad 45', 'ad 46', 'ad 47',
#        'ad 48', 'ad 49', 'ad 5', 'ad 50', 'ad 51', 'ad 52', 'ad 53',
#        'ad 54', 'ad 55', 'ad 56', 'ad 57', 'ad 58', 'ad 59', 'ad 6',
#        'ad 60', 'ad 61', 'ad 62', 'ad 63', 'ad 64', 'ad 65', 'ad 66',
#        'ad 67', 'ad 68', 'ad 69', 'ad 7', 'ad 70', 'ad 8', 'ad 9'],
#       dtype=object)

# %%
df['ad'].nunique()
# Out:
# 70

# %%
df1 = df[(df['revenue'] > 0)]

# %%
df1['ad'].value_counts()
# Out:
# ad 2     193
# ad 3     166
# ad 6     158
# ad 8     112
# ad 32    107
#         ...
# ad 29      2
# ad 45      2
# ad 24      1
# ad 50      1
# ad 36      1
# Name: ad, Length: 69, dtype: int64

# %%
df1['adgroup'].value_counts()
# Out:
# adgroup 3    733
# adgroup 1    532
# adgroup 4     67
# adgroup 2     23
# Name: adgroup, dtype: int64

# %%
np.max(df['revenue'])
# Out:
# 20515.41

# %%
df2 = df[(df['adgroup'] == 'adgroup 1')]

# %%
df2

# %%
df['ad'].value_counts()
# Out:
# ad 3     617
# ad 1     587
# ad 2     512
# ad 7     461
# ad 32    377
#         ...
# ad 36      4
# ad 31      4
# ad 69      4
# ad 47      4
# ad 51      3
# Name: ad, Length: 70, dtype: int64

# %%
df3 = pd.read_csv("/content/drive/MyDrive/SUMMER ANALYTICS IITG/Hackathon/Train_Data.csv", parse_dates= [0])

# %%
df3.head()
# Out:
#         date    campaign    adgroup    ad  ...  clicks  cost  conversions  revenue
# 0 2020-01-08  campaign 1  adgroup 1  ad 1  ...       6  0.08            0     0.00
# 1 2020-01-08  campaign 1  adgroup 2  ad 1  ...       0  0.00            0     0.00
# 2 2020-01-08  campaign 1  adgroup 3  ad 1  ...       4  0.04            0     0.00
# 3 2020-01-08  campaign 1  adgroup 4  ad 1  ...       4  0.08            0     0.00
# 4 2020-01-08  campaign 1  adgroup 1  ad 2  ...     126  1.29            4   925.71
#
# [5 rows x 9 columns]

# %%
df3['revenue'].plot()

# %%
df = pd.get_dummies(df , columns= ['adgroup'])

# %%
df.head()
# Out:
#          date    campaign  ... adgroup_adgroup 3  adgroup_adgroup 4
# 0  01-08-2020  campaign 1  ...                 0                  0
# 1  01-08-2020  campaign 1  ...                 0                  0
# 2  01-08-2020  campaign 1  ...                 1                  0
# 3  01-08-2020  campaign 1  ...                 0                  1
# 4  01-08-2020  campaign 1  ...                 0                  0
#
# [5 rows x 12 columns]

# %%
df = df.drop(['campaign'] , axis = 1)

# %%
df.head()
# Out:
#          date    ad  ...  adgroup_adgroup 3  adgroup_adgroup 4
# 0  01-08-2020  ad 1  ...                  0                  0
# 1  01-08-2020  ad 1  ...                  0                  0
# 2  01-08-2020  ad 1  ...                  1                  0
# 3  01-08-2020  ad 1  ...                  0                  1
# 4  01-08-2020  ad 2  ...                  0                  0
#
# [5 rows x 11 columns]

# %%
X['CIM'] = df['clicks']/df['impressions']

# %%
X['CCN'] = df['conversions']/df['clicks']

# %%
X = df.drop(['clicks' , 'conversions' , 'impressions' , 'campaign' , 'date'] , axis = 1)

# %%
X = pd.get_dummies(X , columns=['ad' , 'adgroup'])

# %% [markdown]
# # NEW

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train = pd.read_csv("/content/drive/MyDrive/SUMMER ANALYTICS IITG/Hackathon/Train_Data.csv" , parse_dates=[0])

# %%
test  = pd.read_csv('/content/drive/MyDrive/SUMMER ANALYTICS IITG/Hackathon/Test_Data.csv' , parse_dates=[0])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4571 entries, 0 to 4570
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         4571 non-null   datetime64[ns]
#  1   campaign     4571 non-null   object
#  2   adgroup      4571 non-null   object
#  3   ad           4571 non-null   object
#  4   impressions  4571 non-null   int64
#  5   clicks       4571 non-null   int64
#  6   cost         4571 non-null   float64
#  7   conversions  4571 non-null   int64
#  8   revenue      4571 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 321.5+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318 entries, 0 to 317
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         318 non-null    datetime64[ns]
#  1   campaign     318 non-null    object
#  2   adgroup      318 non-null    object
#  3   ad           318 non-null    object
#  4   cost         318 non-null    float64
#  5   impressions  318 non-null    int64
#  6   clicks       318 non-null    int64
#  7   conversions  318 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(3)
# memory usage: 20.0+ KB

# %%
train['weekday'] = train['date'].dt.dayofweek

# %%
test['weekday'] = test['date'].dt.dayofweek

# %%
train.head()
# Out:
#         date    campaign    adgroup    ad  ...  cost  conversions  revenue  weekday
# 0 2020-01-08  campaign 1  adgroup 1  ad 1  ...  0.08            0     0.00        2
# 1 2020-01-08  campaign 1  adgroup 2  ad 1  ...  0.00            0     0.00        2
# 2 2020-01-08  campaign 1  adgroup 3  ad 1  ...  0.04            0     0.00        2
# 3 2020-01-08  campaign 1  adgroup 4  ad 1  ...  0.08            0     0.00        2
# 4 2020-01-08  campaign 1  adgroup 1  ad 2  ...  1.29            4   925.71        2
#
# [5 rows x 10 columns]

# %%
test.head()
# Out:
#         date    campaign    adgroup  ... clicks  conversions  weekday
# 0 2021-01-03  campaign 1  adgroup 1  ...     49            1        6
# 1 2021-01-03  campaign 1  adgroup 3  ...     12            0        6
# 2 2021-01-03  campaign 1  adgroup 4  ...      3            0        6
# 3 2021-01-03  campaign 1  adgroup 2  ...      1            0        6
# 4 2021-01-03  campaign 1  adgroup 2  ...      1            0        6
#
# [5 rows x 9 columns]

# %%
train = train.drop(['date'] , axis = 1)

# %%
test = test.drop(['date'] , axis = 1)

# %%
train = train.drop(['campaign'] , axis = 1)
test = test.drop(['campaign'] , axis = 1)

# %%
test.tail()
# Out:
#        adgroup     ad  cost  impressions  clicks  conversions  weekday
# 313  adgroup 4  ad 55  0.01            1       1            0        0
# 314  adgroup 3  ad 55  0.01            5       1            0        0
# 315  adgroup 1  ad 55  0.14           25      11            0        0
# 316  adgroup 3  ad 56  0.06            9       4            0        0
# 317  adgroup 1  ad 56  0.33           67      27            1        0

# %%
y = train['revenue']

# %%
X = train.drop(['revenue'] , axis = 1)

# %%
dfc = X.append(test)

# %%
dfc.tail()
# Out:
#        adgroup     ad  impressions  clicks  cost  conversions  weekday
# 313  adgroup 4  ad 55            1       1  0.01            0        0
# 314  adgroup 3  ad 55            5       1  0.01            0        0
# 315  adgroup 1  ad 55           25      11  0.14            0        0
# 316  adgroup 3  ad 56            9       4  0.06            0        0
# 317  adgroup 1  ad 56           67      27  0.33            1        0

# %%
dfc
# Out:
#        adgroup     ad  impressions  clicks  cost  conversions  weekday
# 0    adgroup 1   ad 1           24       6  0.08            0        2
# 1    adgroup 2   ad 1            1       0  0.00            0        2
# 2    adgroup 3   ad 1           13       4  0.04            0        2
# 3    adgroup 4   ad 1            5       4  0.08            0        2
# 4    adgroup 1   ad 2          247     126  1.29            4        2
# ..         ...    ...          ...     ...   ...          ...      ...
# 313  adgroup 4  ad 55            1       1  0.01            0        0
# 314  adgroup 3  ad 55            5       1  0.01            0        0
# 315  adgroup 1  ad 55           25      11  0.14            0        0
# 316  adgroup 3  ad 56            9       4  0.06            0        0
# 317  adgroup 1  ad 56           67      27  0.33            1        0
#
# [4889 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
dfc['Ad'] = le.fit_transform(dfc['ad'])

# %%
dfc.head()
# Out:
#      adgroup    ad  impressions  clicks  cost  conversions  weekday  Ad
# 0  adgroup 1  ad 1           24       6  0.08            0        2   0
# 1  adgroup 2  ad 1            1       0  0.00            0        2   0
# 2  adgroup 3  ad 1           13       4  0.04            0        2   0
# 3  adgroup 4  ad 1            5       4  0.08            0        2   0
# 4  adgroup 1  ad 2          247     126  1.29            4        2  11

# %%
dfc['Adgroup'] = le.fit_transform(dfc['adgroup'])

# %%
dfc.head()
# Out:
#      adgroup    ad  impressions  clicks  ...  conversions  weekday  Ad  Adgroup
# 0  adgroup 1  ad 1           24       6  ...            0        2   0        0
# 1  adgroup 2  ad 1            1       0  ...            0        2   0        1
# 2  adgroup 3  ad 1           13       4  ...            0        2   0        2
# 3  adgroup 4  ad 1            5       4  ...            0        2   0        3
# 4  adgroup 1  ad 2          247     126  ...            4        2  11        0
#
# [5 rows x 9 columns]

# %%
dfc = dfc.drop(['ad' , 'adgroup'] , axis = 1)

# %%
dfc.head()
# Out:
#    impressions  clicks  cost  conversions  weekday  Ad  Adgroup
# 0           24       6  0.08            0        2   0        0
# 1            1       0  0.00            0        2   0        1
# 2           13       4  0.04            0        2   0        2
# 3            5       4  0.08            0        2   0        3
# 4          247     126  1.29            4        2  11        0

# %%
df_train = dfc.iloc[:-318]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4571 entries, 0 to 4570
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   impressions  4571 non-null   int64
#  1   clicks       4571 non-null   int64
#  2   cost         4571 non-null   float64
#  3   conversions  4571 non-null   int64
#  4   weekday      4571 non-null   int64
#  5   Ad           4571 non-null   int64
#  6   Adgroup      4571 non-null   int64
# dtypes: float64(1), int64(6)
# memory usage: 285.7 KB

# %%
df_test = dfc.iloc[4571:]

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 318 entries, 0 to 317
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   impressions  318 non-null    int64
#  1   clicks       318 non-null    int64
#  2   cost         318 non-null    float64
#  3   conversions  318 non-null    int64
#  4   weekday      318 non-null    int64
#  5   Ad           318 non-null    int64
#  6   Adgroup      318 non-null    int64
# dtypes: float64(1), int64(6)
# memory usage: 19.9 KB

# %%
df_train.head()
# Out:
#    impressions  clicks  cost  conversions  weekday  Ad  Adgroup
# 0           24       6  0.08            0        2   0        0
# 1            1       0  0.00            0        2   0        1
# 2           13       4  0.04            0        2   0        2
# 3            5       4  0.08            0        2   0        3
# 4          247     126  1.29            4        2  11        0

# %%
df_test.head()
# Out:
#    impressions  clicks  cost  conversions  weekday  Ad  Adgroup
# 0          121      49  0.58            1        6   0        0
# 1           22      12  0.17            0        6   0        2
# 2            5       3  0.05            0        6   0        3
# 3            2       1  0.01            0        6   0        1
# 4            3       1  0.01            0        6  11        1

# %%
model.fit(df_train , y)
# Out:
# [11:12:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
np.sqrt(mean_squared_error(y , model.predict(df_train)))
# Out:
# 126.08982453573627

# %%
pred = model.predict(df_test)

# %%
submission = pd.DataFrame({ 'revenue' : pred })
submission.to_csv("my_submission.csv", index=False)

# %%
model1 = XGBRegressor()

# %%
parameters = {'nthread':[4], 
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], 
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
xgb_grid = GridSearchCV(model1,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)

# %%
xgb_grid.fit(X,y)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# Exception ignored in: <function _releaseLock at 0x7f8392e558c0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 221, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-61e7add6ebdd> in <module>()
# ----> 1 xgb_grid.fit(X,y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ...

# %%
submission = pd.DataFrame({ 'revenue' : xgb_grid.predict(df_test) })
submission.to_csv("my_submission2.csv", index=False)

# %% [markdown]
# # RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
rfr = RandomForestRegressor(random_state = 1)
param_grid = {  'bootstrap': [True], 'max_depth': [5, 10, None], 'max_features': ['auto', 'log2'], 'n_estimators': [5, 7, 9, 10, 15 , 50 ,100 , 500 , 1000]}




rfr_grid = GridSearchCV(estimator = rfr, param_grid = param_grid, cv = 3, n_jobs = 1, verbose = 0, return_train_score=True)
rfr_grid.fit(df_train , y)

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y , rfr_grid.predict(df_train)))

# %%
rfr_grid.best_estimator_

# %%
rfr1 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=10, max_features='log2', max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=1,
                      min_samples_split=2, min_weight_fraction_leaf=0.0,
                      n_estimators=7, n_jobs=None, oob_score=False,
                      random_state=1, verbose=0, warm_start=False)

# %%
from xgboost import XGBRegressor
model = XGBRegressor(rfr)

# %%
parameters = {'nthread':[4], 
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], 
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}

# %%
xgb_grid = GridSearchCV(model,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)
xgb_grid.fit(df_train,y)

# %%
np.sqrt(mean_squared_error(y , xgb_grid.predict(df_train)))

# %%
submission = pd.DataFrame({ 'revenue' : xgb_grid.predict(df_test) })
submission.to_csv("my_submission3.csv", index=False)

# %%
df_train_1 = df_train.copy()
df_test_1 = df_test.copy()
df_train_1.head()

# %%
df_train_1.impressions= np.log(df_train_1.impressions+1)
df_train_1.clicks = np.log(df_train_1.clicks+1)
df_train_1.conversions= np.log(df_train_1.conversions+1)
df_test_1.impressions = np.log(df_test_1.impressions+1)
df_test_1.clicks = np.log(df_test_1.clicks+1)
df_test_1.conversions= np.log(df_test_1.conversions+1)

# %%
model1 = XGBRegressor()
parameters = {'nthread':[4], 
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], 
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}

xgb_grid = GridSearchCV(model1,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)
xgb_grid.fit(df_train_1 , y)

# %%
np.sqrt(mean_squared_error(y , xgb_grid.predict(df_train_1)))

# %%
submission = pd.DataFrame({ 'revenue' : xgb_grid.predict(df_test_1) })
submission.to_csv("my_submission4.csv", index=False)

# %%
y_1 = y.copy()

# %%
y_1 = np.log(y_1 + 1)

# %%
xgb_grid.fit(df_train_1 , y_1)

# %%
np.sqrt(mean_squared_error(y_1 , xgb_grid.predict(df_train_1)))

# %%
pred_y = xgb_grid.predict(df_test_1)

# %%
pred_y = np.exp(pred_y) - 1

# %%
submission = pd.DataFrame({ 'revenue' : pred_y })
submission.to_csv("my_submission5.csv", index=False)

# %% [markdown]
# # ANN

# %%
import tensorflow as tf

# %%
ann1 = tf.keras.models.Sequential()

# %%
ann1.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann1.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann1.add(tf.keras.layers.Dense(units=1))

# %%
ann1.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
History = ann1.fit(x = df_train, y = y, batch_size = 32, epochs = 150, verbose = 0)

# %%
plt.plot(History.history['mean_absolute_error'])
plt.title('Loss Function Over Epochs')
plt.ylabel('MAE')
plt.xlabel('No. epoch')
plt.show()

# %%
def buildModel(optimizer):
    
    classifier = tf.keras.models.Sequential()
    
    
    classifier.add(tf.keras.layers.Dense(units = 128, activation = 'relu'))
    
    
    classifier.add(tf.keras.layers.Dense(units = 64, activation = 'relu'))
    
    
    classifier.add(tf.keras.layers.Dense(units = 32, activation = 'relu'))
    
    
    classifier.add(tf.keras.layers.Dense(units = 1, activation = 'linear'))
    
    classifier.compile(loss='mean_absolute_error', optimizer=optimizer, metrics=['mean_absolute_error'])
    
    return classifier

# %%
from sklearn.model_selection import GridSearchCV 
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor

classifier = KerasRegressor(build_fn = buildModel)

parameters = {'batch_size': [16, 32, 64, 128],
              'epochs': [100, 150],
              'optimizer': ['adam', 'rmsprop']}
grid_search = GridSearchCV(estimator = classifier,
                           param_grid = parameters,
                           scoring = 'neg_mean_absolute_error',
                           cv = 5)
grid_search = grid_search.fit(df_train, y, verbose = 0)

# %%
y_pred = grid_search.predict(df_test)

# %%
y_pred
# Out:
# array([ 1.20982742e+02,  9.13347118e-04,  9.13347118e-04,  9.13347118e-04,
#        -2.84632668e-03, -1.69573337e-01,  1.08601776e+02,  9.13347118e-04,
#         1.09823288e+02,  9.13347118e-04,  3.76261261e+02,  9.04601999e-04,
#         9.13347118e-04,  2.91464294e+02,  9.13347118e-04,  1.02146301e+02,
#         2.57828645e-03,  1.17125839e+02,  4.71837632e-03,  1.17396049e+02,
#         9.13347118e-04,  2.23074436e+00,  9.13347118e-04,  3.71581421e+02,
#         9.13347118e-04,  9.13347118e-04,  5.03905182e+02,  1.15406952e+02,
#         9.13347118e-04,  9.13347118e-04,  4.96485138e+02,  9.13347118e-04,
#         9.98864075e+02,  2.48320511e+02,  1.49526245e+02,  9.13347118e-04,
#         1.18699936e+02, -1.38853371e-01,  9.13347118e-04,  9.13347118e-04,
#         6.57572448e-02,  3.36640477e-02,  9.13347118e-04,  1.46497171e-02,
#         1.06765609e-02,  9.13347118e-04,  9.13347118e-04,  9.13347118e-04,
# ...

# %%
submission = pd.DataFrame({ 'revenue' : y_pred })
submission.to_csv("my_submission6.csv")

# %%
grid_search.best_params_
# Out:
# {'batch_size': 32, 'epochs': 150, 'optimizer': 'adam'}

# %% [markdown]
# # Trying Again Using One Hot Encoding

# %%
df = pd.get_dummies(dfc, columns =["adgroup", "ad"])

# %%
df.head()
# Out:
#    impressions  clicks  cost  conversions  ...  ad_ad 74  ad_ad 75  ad_ad 8  ad_ad 9
# 0           24       6  0.08            0  ...         0         0        0        0
# 1            1       0  0.00            0  ...         0         0        0        0
# 2           13       4  0.04            0  ...         0         0        0        0
# 3            5       4  0.08            0  ...         0         0        0        0
# 4          247     126  1.29            4  ...         0         0        0        0
#
# [5 rows x 84 columns]

# %%
df_train = df.iloc[:-318]

# %%
df_test = df.iloc[4571:]

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
model = XGBRegressor()



parameters = {'nthread':[4], 
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], 
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}


xgb_grid = GridSearchCV(model,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)
xgb_grid.fit(df_train,y)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  18 out of  18 | elapsed:   49.3s finished
# GridSearchCV(cv=2, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_...
#                                     scale_pos_weight=1, seed=None, silent=None,
# ...

# %%
np.sqrt(mean_squared_error(y , xgb_grid.predict(df_train)))
# Out:
# 60.12807643372518

# %%
submission = pd.DataFrame({ 'revenue' : xgb_grid.predict(df_test) })
submission.to_csv("my_submission6.csv", index=False)

# %% [markdown]
# # Trying Ensembling  Or Stacking

# %% [markdown]
# Random Forest

# %%
from scipy import stats
from sklearn.model_selection import train_test_split, StratifiedKFold, RepeatedKFold, KFold, ParameterGrid, GridSearchCV
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR, LinearSVR
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import RobustScaler

# %%
# !pip install Pancake
# Out:
# ...
#      |████████████████████████████████| 92kB 11.7MB/s
# ...
#      |████████████████████████████████| 2.3MB 38.4MB/s
# ...
#   Created wheel for Pancake: filename=pancake-1.1.2-cp37-none-any.whl size=33991 sha256=9fd7ca98d038da96ab253d994bac0c01e93580ca86ca22d678b7224160a29d7e
#   Stored in directory: /root/.cache/pip/wheels/0a/dd/0f/6000f7db7c1b9856842c88583d7277b04341e91c1c15adbe75
# Successfully built Pancake
# ...

# %%
skf = RepeatedKFold(n_repeats=10,n_splits=5,random_state=123)
hypers = {'max_features':[2,4,6,8]}

regMod_3 = RandomForestRegressor(n_estimators=50,random_state=123)
grid = GridSearchCV(estimator=regMod_3, param_grid=hypers, cv=skf, scoring='neg_mean_squared_error', 
                    n_jobs=4)
grid.fit(df_train, y)
# Out:
# GridSearchCV(cv=RepeatedKFold(n_repeats=10, n_splits=5, random_state=123),
#              error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=50, n_jobs=None,
#                                              oob_score=False, random_state=123,
# ...

# %%
grid.best_params_
# Out:
# {'max_features': 8}

# %%
np.sqrt(mean_squared_error(y , grid.predict(df_train)))
# Out:
# 140.65156069131012

# %%
from sklearn.ensemble import StackingRegressor

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import StackingRegressor
from matplotlib import pyplot
 

def get_stacking():
	
	level0 = list()
	level0.append(('knn', KNeighborsRegressor()))
	level0.append(('cart', DecisionTreeRegressor()))
	level0.append(('svm', SVR()))
	
	level1 = LinearRegression()
	
	model = StackingRegressor(estimators=level0, final_estimator=level1, cv=5)
	return model
 
def get_models():
	models = dict()
	models['knn'] = KNeighborsRegressor()
	models['cart'] = DecisionTreeRegressor()
	models['svm'] = SVR()
	models['stacking'] = get_stacking()
	return models
 

def evaluate_model(model, df_train, y):
	cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
	scores = cross_val_score(model, df_train, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
	return scores
 


models = get_models()
results, names = list(), list()
for name, model in models.items():
	scores = evaluate_model(model, df_train, y)
	results.append(scores)
	names.append(name)
	print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))

pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()
# Out:
# >knn -145.177 (24.983)
# >cart -86.097 (13.099)
# >svm -199.067 (46.508)
# >stacking -92.216 (14.692)

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import StackingRegressor

level0 = list()
level0.append(('knn', KNeighborsRegressor()))
level0.append(('cart', DecisionTreeRegressor()))
level0.append(('svm', SVR()))
# define meta learner model
level1 = LinearRegression()
# define the stacking ensemble
model = StackingRegressor(estimators=level0, final_estimator=level1, cv=5)
# fit the model on all available data
model.fit(df_train, y)
# Out:
# StackingRegressor(cv=5,
#                   estimators=[('knn',
#                                KNeighborsRegressor(algorithm='auto',
#                                                    leaf_size=30,
#                                                    metric='minkowski',
#                                                    metric_params=None,
#                                                    n_jobs=None, n_neighbors=5,
#                                                    p=2, weights='uniform')),
#                               ('cart',
#                                DecisionTreeRegressor(ccp_alpha=0.0,
#                                                      criterion='mse',
#                                                      max_depth=None,
#                                                      max_features=None,
#                                                      max_leaf_nodes=None,
#                                                      min_impurity_decrease=0.0,
# ...

# %%
np.sqrt(mean_squared_error(y , model.predict(df_train)))
# Out:
# 129.71615052568433

# %%
xgb_grid.best_params_
# Out:
# {'colsample_bytree': 0.7,
#  'learning_rate': 0.05,
#  'max_depth': 7,
#  'min_child_weight': 4,
#  'n_estimators': 500,
#  'nthread': 4,
#  'objective': 'reg:linear',
#  'silent': 1,
#  'subsample': 0.7}

# %%
submission = pd.DataFrame({ 'revenue' : model.predict(df_test) })
submission.to_csv("my_submission7.csv", index=False)

# %%
# !pip install mlens
# Out:
# ...
#      |████████████████████████████████| 235kB 27.4MB/s
# ...

# %%
from math import sqrt
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from mlens.ensemble import SuperLearner
 
# create a list of base-models
def get_models():
	models = list()
	models.append(LinearRegression())
	models.append(ElasticNet())
	models.append(SVR(gamma='scale'))
	models.append(DecisionTreeRegressor())
	models.append(KNeighborsRegressor())
	models.append(AdaBoostRegressor())
	models.append(BaggingRegressor(n_estimators=10))
	models.append(RandomForestRegressor(n_estimators=10))
	models.append(ExtraTreesRegressor(n_estimators=10))
	return models
 
# cost function for base models
def rmse(yreal, yhat):
	return sqrt(mean_squared_error(yreal, yhat))
 
# create the super learner
def get_super_learner(x):
	ensemble = SuperLearner(scorer=rmse, folds=10, shuffle=False, sample_size=len(x))
	# add base models
	models = get_models()
	ensemble.add(models)
	# add the meta model
	ensemble.add_meta(LinearRegression())
	return ensemble

# create the super learner
ensemble = get_super_learner(df_train)
# fit the super learner
ensemble.fit(df_train, y)
# Out:
# SuperLearner(array_check=None, backend=None, folds=10,
#        layers=[Layer(backend='threading', dtype=<class 'numpy.float32'>, n_jobs=-1,
#    name='layer-1', propagate_features=None, raise_on_exception=True,
#    random_state=None, shuffle=False,
#    stack=[Group(backend='threading', dtype=<class 'numpy.float32'>,
#    indexer=FoldIndex(X=None, folds=10, raise_on_e...73623b0>)],
#    n_jobs=-1, name='group-9', raise_on_exception=True, transformers=[])],
#    verbose=0)],
#        model_selection=False, n_jobs=None, raise_on_exception=True,
#        random_state=None, sample_size=4571,
#        scorer=<function rmse at 0x7f39873623b0>, shuffle=False,
#        verbose=False)

# %%
rmse(y , ensemble.predict(df_train))
# Out:
# 1091.9840343498986

# %% [markdown]
# # Trying by taking ratio in columns

# %%
df_train.head()
# Out:
#    impressions  clicks  cost  conversions  ...  ad_ad 74  ad_ad 75  ad_ad 8  ad_ad 9
# 0           24       6  0.08            0  ...         0         0        0        0
# 1            1       0  0.00            0  ...         0         0        0        0
# 2           13       4  0.04            0  ...         0         0        0        0
# 3            5       4  0.08            0  ...         0         0        0        0
# 4          247     126  1.29            4  ...         0         0        0        0
#
# [5 rows x 84 columns]

# %%
df['ci'] = (df.clicks)/(df.impressions)

# %%
df2 = df.drop(['impressions' , 'clicks'] , axis = 1)

# %%
X_train = df2.iloc[:-318]

# %%
X_test = df2.iloc[4571:]

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
rfr = RandomForestRegressor()
model = XGBRegressor(rfr)



parameters = {'nthread':[4], 
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], 
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}


xgb_grid = GridSearchCV(model,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)
xgb_grid.fit(X_train,y)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  18 out of  18 | elapsed:   48.7s finished
# GridSearchCV(cv=2, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0,
#                                     max_depth=RandomForestRegressor(bootstrap=True,
#                                                                     ccp_alpha=0.0,
#                                                                     criterion='mse',
#                                                                     max_depth=None,
# ...

# %%
submission = pd.DataFrame({ 'revenue' : xgb_grid.predict(X_test) })
submission.to_csv("my_submission8.csv", index=False)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
df3 = df.copy()

# %%
df3.head()
# Out:
#    impressions  clicks  cost  conversions  ...  ad_ad 75  ad_ad 8  ad_ad 9        ci
# 0           24       6  0.08            0  ...         0        0        0  0.250000
# 1            1       0  0.00            0  ...         0        0        0  0.000000
# 2           13       4  0.04            0  ...         0        0        0  0.307692
# 3            5       4  0.08            0  ...         0        0        0  0.800000
# 4          247     126  1.29            4  ...         0        0        0  0.510121
#
# [5 rows x 85 columns]

# %%
df3.drop(['ci'] , axis = 1)

# %%
df3 = sc.fit_transform(df3)

# %%
df3
# Out:
# array([[-3.45974972e-01, -3.73584636e-01, -1.84437465e-01, ...,
#         -2.01632334e-01, -5.73009452e-02, -8.14519691e-01],
#        [-4.64782033e-01, -4.35071786e-01, -1.90193355e-01, ...,
#         -2.01632334e-01, -5.73009452e-02, -1.88505795e+00],
#        [-4.02795740e-01, -3.94080353e-01, -1.87315410e-01, ...,
#         -2.01632334e-01, -5.73009452e-02, -5.67472400e-01],
#        ...,
#        [-3.40809447e-01, -3.22345345e-01, -1.80120548e-01, ...,
#         -2.01632334e-01, -5.73009452e-02, -9.10613033e-04],
#        [-4.23457838e-01, -3.94080353e-01, -1.85876438e-01, ...,
#         -2.01632334e-01, -5.73009452e-02,  1.81211783e-02],
#        [-1.23857421e-01, -1.58379612e-01, -1.66450311e-01, ...,
#         -2.01632334e-01, -5.73009452e-02, -1.59414188e-01]])

# %%
X_train = df3[:-318]

# %%
X_test = df3[4571:]

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
rfr = RandomForestRegressor()
model = XGBRegressor(rfr)



parameters = {'nthread':[4], 
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], 
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}


xgb_grid = GridSearchCV(model,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)
xgb_grid.fit(X_train,y)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  18 out of  18 | elapsed:   49.9s finished
# GridSearchCV(cv=2, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0,
#                                     max_depth=RandomForestRegressor(bootstrap=True,
#                                                                     ccp_alpha=0.0,
#                                                                     criterion='mse',
#                                                                     max_depth=None,
# ...

# %%
submission = pd.DataFrame({ 'revenue' : xgb_grid.predict(X_test) })
submission.to_csv("my_submission9.csv", index=False)

# %%
df2 = sc.fit_transform(df3)

# %%
X_train = df2[:-318]

# %%
X_test = df2[4571:]

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
rfr = RandomForestRegressor()
model = XGBRegressor(rfr)



parameters = {'nthread':[4], 
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], 
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}


xgb_grid = GridSearchCV(model,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)
xgb_grid.fit(X_train,y)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  18 out of  18 | elapsed:   47.0s finished
# GridSearchCV(cv=2, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0,
#                                     max_depth=RandomForestRegressor(bootstrap=True,
#                                                                     ccp_alpha=0.0,
#                                                                     criterion='mse',
#                                                                     max_depth=None,
# ...

# %%
submission = pd.DataFrame({ 'revenue' : xgb_grid.predict(X_test) })
submission.to_csv("my_submission10.csv", index=False)

# %% [markdown]
# # Using Test Train Split

# %%
train.head()
# Out:
#      adgroup    ad  impressions  clicks  cost  conversions  revenue  weekday
# 0  adgroup 1  ad 1           24       6  0.08            0     0.00        2
# 1  adgroup 2  ad 1            1       0  0.00            0     0.00        2
# 2  adgroup 3  ad 1           13       4  0.04            0     0.00        2
# 3  adgroup 4  ad 1            5       4  0.08            0     0.00        2
# 4  adgroup 1  ad 2          247     126  1.29            4   925.71        2

# %%
y = train['revenue']
X = train.drop(['revenue'] , axis = 1)

# %%
dfc = X.append(test)
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dfc['Ad'] = le.fit_transform(dfc['ad'])
dfc['Adgroup'] = le.fit_transform(dfc['adgroup'])
dfc = dfc.drop(['ad' , 'adgroup'] , axis = 1)
X_train = dfc.iloc[:-318]
X_test = dfc.iloc[4571:]

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X_train, y , test_size = 0.2 , random_state = 0)

# %%
X_train.shape
# Out:
# (3656, 7)

# %%
X_test.shape
# Out:
# (915, 7)

# %%
from xgboost import XGBRegressor

# %%
X_train['ci'] = (X_train.clicks)/(X_train.impressions)
X_test['ci'] = (X_test.clicks)/(X_test.impressions)
X_train = X_train.drop(['impressions' , 'clicks'] , axis = 1)
X_test = X_test.drop(['impressions' , 'clicks'] , axis = 1)

# %%
X_train.shape
# Out:
# (3656, 6)

# %%
from sklearn.model_selection import GridSearchCV

model = XGBRegressor()



parameters = {'nthread':[4], 
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], 
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}


xgb_grid = GridSearchCV(model,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)
xgb_grid.fit(X_train,y_train)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  18 out of  18 | elapsed:   18.6s finished
# GridSearchCV(cv=2, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_...
#                                     scale_pos_weight=1, seed=None, silent=None,
# ...

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test , xgb_grid.predict(X_test)))
# Out:
# 249.48143532213496

# %% [markdown]
# # Feature Engineering

# %%
df = pd.read_csv("/content/drive/MyDrive/SUMMER ANALYTICS IITG/Hackathon/Train_Data.csv")

# %%
df['ci'] = (df.clicks)/(df.impressions)

# %%
df.head(20)

# %%
sns.scatterplot(x = df['ci'] , y = df['revenue'] , data= df)

# %%
sns.scatterplot(x = df['clicks'] , y= df['impressions'] , data = df)

# %%
sns.scatterplot(x = df['conversions'] , y = df['impressions'] , data = df)

# %%
sns.scatterplot(x = df['cost'] , y = df['impressions'] , data = df)

# %%
sns.scatterplot(x = df['revenue'] , y = df['impressions'] , data = df)

# %%
sns.scatterplot(x = df['conversions'] , y = df['revenue'] , data = df)

# %%
sns.scatterplot(x = df['impressions'] , y = df['revenue'] , data = df)

# %%
sns.scatterplot(x = df['conversions'] , y = df['cost'] , data = df)

# %%
sns.scatterplot(x = df['conversions'] , y = df['clicks'] , data = df)

# %%
#dropping clicks , conversions

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#          date    campaign    adgroup    ad  impressions  cost  revenue
# 0  01-08-2020  campaign 1  adgroup 1  ad 1           24  0.08     0.00
# 1  01-08-2020  campaign 1  adgroup 2  ad 1            1  0.00     0.00
# 2  01-08-2020  campaign 1  adgroup 3  ad 1           13  0.04     0.00
# 3  01-08-2020  campaign 1  adgroup 4  ad 1            5  0.08     0.00
# 4  01-08-2020  campaign 1  adgroup 1  ad 2          247  1.29   925.71

# %%
df1['date'] = pd.to_datetime(df1['date'])

# %%
df1['weekday'] = df1['date'].dt.dayofweek

# %%
df1 = df1.drop(['date'] , axis = 1)

# %%
df1.head()
# Out:
#      campaign    adgroup    ad  impressions  cost  revenue  weekday
# 0  campaign 1  adgroup 1  ad 1           24  0.08     0.00        2
# 1  campaign 1  adgroup 2  ad 1            1  0.00     0.00        2
# 2  campaign 1  adgroup 3  ad 1           13  0.04     0.00        2
# 3  campaign 1  adgroup 4  ad 1            5  0.08     0.00        2
# 4  campaign 1  adgroup 1  ad 2          247  1.29   925.71        2

# %%
df1 = df1.drop(['campaign'] , axis = 1)

# %%
df1.head()
# Out:
#      adgroup    ad  impressions  ...  revenue        ci  weekday
# 0  adgroup 1  ad 1           24  ...     0.00  0.250000        2
# 1  adgroup 2  ad 1            1  ...     0.00  0.000000        2
# 2  adgroup 3  ad 1           13  ...     0.00  0.307692        2
# 3  adgroup 4  ad 1            5  ...     0.00  0.800000        2
# 4  adgroup 1  ad 2          247  ...   925.71  0.510121        2
#
# [5 rows x 9 columns]

# %%
df1['ccl'] = (df1.cost)/df1.clicks

# %%
df1.head()

# %%
df1['ccl'] = df1['ccl'].replace(np.nan, 0)
df1['ccl'] = df1['ccl'].replace(np.inf, 0)

# %%
df1.head()
# Out:
#      adgroup    ad  impressions  clicks  ...  revenue        ci  weekday       ccl
# 0  adgroup 1  ad 1           24       6  ...     0.00  0.250000        2  0.013333
# 1  adgroup 2  ad 1            1       0  ...     0.00  0.000000        2  0.000000
# 2  adgroup 3  ad 1           13       4  ...     0.00  0.307692        2  0.010000
# 3  adgroup 4  ad 1            5       4  ...     0.00  0.800000        2  0.020000
# 4  adgroup 1  ad 2          247     126  ...   925.71  0.510121        2  0.010238
#
# [5 rows x 10 columns]

# %%
df1['cpa'] = (df1.cost)/df.conversions

# %%
df1['cpa'] = df1['cpa'].replace(np.nan, 0)

# %%
df1 = df1.drop(['clicks' , 'impressions' , 'cost'] , axis = 1)

# %%
df1.head()
# Out:
#      adgroup    ad  conversions  revenue        ci  weekday       ccl     cpa
# 0  adgroup 1  ad 1            0     0.00  0.250000        2  0.013333  0.0000
# 1  adgroup 2  ad 1            0     0.00  0.000000        2  0.000000  0.0000
# 2  adgroup 3  ad 1            0     0.00  0.307692        2  0.010000  0.0000
# 3  adgroup 4  ad 1            0     0.00  0.800000        2  0.020000  0.0000
# 4  adgroup 1  ad 2            4   925.71  0.510121        2  0.010238  0.3225

# %%
df1['cpa'] = df1['cpa'].replace(np.inf, 0)

# %%
df1.head()

# %%
test  = pd.read_csv('/content/drive/MyDrive/SUMMER ANALYTICS IITG/Hackathon/Test_Data.csv' , parse_dates=[0])
test = test.drop(['campaign'] , axis = 1)
test['weekday'] = test['date'].dt.weekday
test = test.drop(['date'] , axis =1)
test['ci'] = (test.clicks)/(test.impressions)
test['ccl'] = (test.cost)/test.clicks
test['cpa'] = (test.cost)/test.conversions
test = test.drop(['clicks', 'cost'  , 'impressions'] , axis = 1)
test.head()
# Out:
#      adgroup    ad  conversions  weekday        ci       ccl   cpa
# 0  adgroup 1  ad 1            1        6  0.404959  0.011837  0.58
# 1  adgroup 3  ad 1            0        6  0.545455  0.014167   inf
# 2  adgroup 4  ad 1            0        6  0.600000  0.016667   inf
# 3  adgroup 2  ad 1            0        6  0.500000  0.010000   inf
# 4  adgroup 2  ad 2            0        6  0.333333  0.010000   inf

# %%
test['ccl']= test['ccl'].replace(np.nan , 0)
test['cpa']= test['cpa'].replace(np.nan , 0)
test['ccl']= test['ccl'].replace(np.inf , 0)
test['cpa']= test['cpa'].replace(np.inf , 0)

# %%
df1.head()
# Out:
#      adgroup    ad  conversions  revenue        ci  weekday       ccl     cpa
# 0  adgroup 1  ad 1            0     0.00  0.250000        2  0.013333  0.0000
# 1  adgroup 2  ad 1            0     0.00  0.000000        2  0.000000  0.0000
# 2  adgroup 3  ad 1            0     0.00  0.307692        2  0.010000  0.0000
# 3  adgroup 4  ad 1            0     0.00  0.800000        2  0.020000  0.0000
# 4  adgroup 1  ad 2            4   925.71  0.510121        2  0.010238  0.3225

# %%
dfc = df1.append(test)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dfc['Ad'] = le.fit_transform(dfc['ad'])
dfc['Adgroup'] = le.fit_transform(dfc['adgroup'])
dfc = dfc.drop(['ad' , 'adgroup'] , axis = 1)
X_train = dfc.iloc[:-318]
X_test = dfc.iloc[4571:]

# %%
X_test.head()
# Out:
#    conversions  revenue        ci  weekday       ccl   cpa  Ad  Adgroup
# 0            1      NaN  0.404959        6  0.011837  0.58   0        0
# 1            0      NaN  0.545455        6  0.014167  0.00   0        2
# 2            0      NaN  0.600000        6  0.016667  0.00   0        3
# 3            0      NaN  0.500000        6  0.010000  0.00   0        1
# 4            0      NaN  0.333333        6  0.010000  0.00  11        1

# %%
X_train.head()
# Out:
#    conversions  revenue        ci  weekday       ccl     cpa  Ad  Adgroup
# 0            0     0.00  0.250000        2  0.013333  0.0000   0        0
# 1            0     0.00  0.000000        2  0.000000  0.0000   0        1
# 2            0     0.00  0.307692        2  0.010000  0.0000   0        2
# 3            0     0.00  0.800000        2  0.020000  0.0000   0        3
# 4            4   925.71  0.510121        2  0.010238  0.3225  11        0

# %%
y = X_train['revenue']

# %%
X_train = X_train.drop(['revenue'] , axis = 1)
X_test = X_test.drop(['revenue'] , axis = 1)

# %%
X_train.head()
# Out:
#    conversions        ci  weekday       ccl     cpa  Ad  Adgroup
# 0            0  0.250000        2  0.013333  0.0000   0        0
# 1            0  0.000000        2  0.000000  0.0000   0        1
# 2            0  0.307692        2  0.010000  0.0000   0        2
# 3            0  0.800000        2  0.020000  0.0000   0        3
# 4            4  0.510121        2  0.010238  0.3225  11        0

# %%
X_test.head()
# Out:
#    conversions        ci  weekday       ccl   cpa  Ad  Adgroup
# 0            1  0.404959        6  0.011837  0.58   0        0
# 1            0  0.545455        6  0.014167  0.00   0        2
# 2            0  0.600000        6  0.016667  0.00   0        3
# 3            0  0.500000        6  0.010000  0.00   0        1
# 4            0  0.333333        6  0.010000  0.00  11        1

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor
model = XGBRegressor()



parameters = {'nthread':[4], 
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], 
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}


xgb_grid = GridSearchCV(model,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)
xgb_grid.fit(X_train,y)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  18 out of  18 | elapsed:   17.4s finished
# GridSearchCV(cv=2, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_...
#                                     scale_pos_weight=1, seed=None, silent=None,
# ...

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y , xgb_grid.predict(X_train)))
# Out:
# 103.40338093003851

# %%
submission = pd.DataFrame({ 'revenue' : xgb_grid.predict(X_test) })
submission.to_csv("my_submission11.csv", index=False)

# %% [markdown]
# # More Feature Engineering

# %%
df = pd.read_csv("/content/drive/MyDrive/SUMMER ANALYTICS IITG/Hackathon/Train_Data.csv" , parse_dates=[0])

# %%
df.describe()

# %%
test  = pd.read_csv('/content/drive/MyDrive/SUMMER ANALYTICS IITG/Hackathon/Test_Data.csv' , parse_dates=[0])

# %%
uv=np.percentile(df.revenue,[99])[0]
df.revenue[(df.revenue>3*uv)]=3*uv
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1 = df.copy()

# %%
dfc = df1.append(test)

# %%
uv=np.percentile(dfc.impressions,[99])[0]
dfc.impressions[(dfc.impressions>3*uv)]=3*uv
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
uv=np.percentile(dfc.clicks,[99])[0]
dfc.clicks[(dfc.clicks>3*uv)]=3*uv
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
uv=np.percentile(dfc.conversions,[99])[0]
dfc.clicks[(dfc.conversions>3*uv)]=3*uv
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
uv=np.percentile(dfc.cost,[99])[0]
dfc.cost[(dfc.cost>3*uv)]=3*uv
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dfc.describe()

# %%
dfc['weekday'] = dfc['date'].dt.weekday

# %%
dfc = dfc.drop(['date'], axis = 1)

# %%
dfc = dfc.drop(['campaign'] , axis = 1)

# %%
dfc.head()
# Out:
#      adgroup    ad  impressions  clicks  cost  conversions  revenue  weekday
# 0  adgroup 1  ad 1         24.0     6.0  0.08            0     0.00        2
# 1  adgroup 2  ad 1          1.0     0.0  0.00            0     0.00        2
# 2  adgroup 3  ad 1         13.0     4.0  0.04            0     0.00        2
# 3  adgroup 4  ad 1          5.0     4.0  0.08            0     0.00        2
# 4  adgroup 1  ad 2        247.0   126.0  1.29            4   925.71        2

# %%
dfc['ci'] = dfc.clicks/dfc.impressions

# %%
dfc = dfc.drop(['clicks' , 'impressions'] , axis = 1)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dfc['Ad'] = le.fit_transform(dfc['ad'])
dfc['Adgroup'] = le.fit_transform(dfc['adgroup'])
dfc = dfc.drop(['ad' , 'adgroup'] , axis = 1)
X_train = dfc.iloc[:-318]
X_test = dfc.iloc[4571:]

# %%
X_train.head()
# Out:
#    cost  conversions  revenue  weekday        ci  Ad  Adgroup
# 0  0.08            0     0.00        2  0.250000   0        0
# 1  0.00            0     0.00        2  0.000000   0        1
# 2  0.04            0     0.00        2  0.307692   0        2
# 3  0.08            0     0.00        2  0.800000   0        3
# 4  1.29            4   925.71        2  0.510121  11        0

# %%
X_test.head()
# Out:
#    cost  conversions  revenue  weekday        ci  Ad  Adgroup
# 0  0.58            1      NaN        6  0.404959   0        0
# 1  0.17            0      NaN        6  0.545455   0        2
# 2  0.05            0      NaN        6  0.600000   0        3
# 3  0.01            0      NaN        6  0.500000   0        1
# 4  0.01            0      NaN        6  0.333333  11        1

# %%
X_test = X_test.drop(['revenue'] , axis = 1)
X_test.shape
# Out:
# (318, 6)

# %%
y = X_train['revenue']
X_train = X_train.drop(['revenue'] , axis = 1)
X_train.shape
# Out:
# (4571, 6)

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor
model = XGBRegressor()



parameters = {'nthread':[4], 
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], 
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}


xgb_grid = GridSearchCV(model,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)
xgb_grid.fit(X_train,y)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  18 out of  18 | elapsed:   16.8s finished
# GridSearchCV(cv=2, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_...
#                                     scale_pos_weight=1, seed=None, silent=None,
# ...

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y , xgb_grid.predict(X_train)))
# Out:
# 75.97375614662707

# %%
submission = pd.DataFrame({ 'revenue' : xgb_grid.predict(X_test) })
submission.to_csv("my_submission12.csv", index=False)

# %% [markdown]
# # Using 1.5 * uv

# %%
df = pd.read_csv("/content/drive/MyDrive/SUMMER ANALYTICS IITG/Hackathon/Train_Data.csv" , parse_dates=[0])
test  = pd.read_csv('/content/drive/MyDrive/SUMMER ANALYTICS IITG/Hackathon/Test_Data.csv' , parse_dates=[0])

# %%
uv=np.percentile(df.revenue,[99])[0]
df.revenue[(df.revenue>1.5*uv)]=1.5*uv

# %%
dfc = df1.append(test)

# %%
uv=np.percentile(dfc.impressions,[99])[0]
dfc.impressions[(dfc.impressions>1.5*uv)]=1.5*uv

# %%
uv=np.percentile(dfc.clicks,[99])[0]
dfc.clicks[(dfc.clicks>1.5*uv)]=1.5*uv

# %%
uv=np.percentile(dfc.conversions,[99])[0]
dfc.conversions[(dfc.conversions>1.5*uv)]=1.5*uv

# %%
uv=np.percentile(dfc.cost,[99])[0]
dfc.cost[(dfc.cost>1.5*uv)]=1.5*uv

# %%
dfc['weekday'] = dfc['date'].dt.weekday
dfc = dfc.drop(['date'], axis = 1)
dfc = dfc.drop(['campaign'] , axis = 1)
dfc['ci'] = dfc.clicks/dfc.impressions
dfc = dfc.drop(['clicks' , 'impressions'] , axis = 1)

# %%
from sklearn.preprocessing import LabelEncoder
Adgroup = LabelEncoder()
dfc['adgroup']=Adgroup.fit_transform(dfc["adgroup"])
Ad = LabelEncoder()
dfc['ad']=Ad.fit_transform(dfc["ad"])
dfc = dfc.drop(['adgroup','ad'],axis=1)

# %%
X_train = dfc.iloc[:-318]
X_test = dfc.iloc[4571:]

# %%
X_test = X_test.drop(['revenue'] , axis = 1)
X_test.shape
# Out:
# (318, 4)

# %%
y = X_train['revenue']
X_train = X_train.drop(['revenue'] , axis = 1)
X_train.shape
# Out:
# (4571, 4)

# %%
X_train.head()
# Out:
#    cost  conversions  weekday        ci
# 0  0.08            0        2  0.250000
# 1  0.00            0        2  0.000000
# 2  0.04            0        2  0.307692
# 3  0.08            0        2  0.800000
# 4  1.29            4        2  0.510121

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor
model = XGBRegressor()



parameters = {'nthread':[4], 
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], 
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}


xgb_grid = GridSearchCV(model,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)
xgb_grid.fit(X_train,y)
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y , xgb_grid.predict(X_train)))
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  18 out of  18 | elapsed:   20.3s finished
# 94.32505684878662

# %%
submission = pd.DataFrame({ 'revenue' : xgb_grid.predict(X_test) })
submission.to_csv("my_submission15.csv", index=False)

# %% [markdown]
# # Using 2*uv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import mean
from numpy import std

## Import Logistic regression and SVC
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

## Import Confusion matrix, plot confusion matrix, classification report, accuracy score, auc-roc score and roc curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import plot_roc_curve
from xgboost.sklearn import XGBRegressor
from sklearn.ensemble import RandomForestRegressor

import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

## Import Label encoder, label binarizer and Standard Scaler
from sklearn.preprocessing import LabelEncoder,LabelBinarizer,StandardScaler
## ================================ ##
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings("ignore")

from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import RepeatedKFold

from sklearn import preprocessing
from sklearn.pipeline import Pipeline
import keras
import keras.backend as kb
import tensorflow as tf

from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import StackingRegressor

from math import sqrt
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor

# %% [markdown]
# # Arpit

# %%
train=pd.read_csv('/content/drive/MyDrive/SUMMER ANALYTICS IITG/Hackathon/Train_Data.csv',parse_dates=[0])
test=pd.read_csv('/content/drive/MyDrive/SUMMER ANALYTICS IITG/Hackathon/Test_Data.csv',parse_dates=[0])

# %%
train['weekday'] = train['date'].dt.dayofweek
test['weekday'] = train['date'].dt.dayofweek

# %%
train =train.drop(['date','campaign'], axis = 1)
test =test.drop(['date','campaign'], axis = 1)

# %%
y = train.revenue
X = train.drop('revenue', axis=1)
X

# %%
df_appended = X.append(test)
Adgroup = LabelEncoder()
df_appended['adgroup']=Adgroup.fit_transform(df_appended["adgroup"])
Ad = LabelEncoder()
df_appended['ad']=Ad.fit_transform(df_appended["ad"])
df_appended = df_appended.drop(['adgroup','ad'],axis=1)
df_appended

# %%
X_train = df_appended.iloc[:-318]
X_test = df_appended.iloc[4571:]

# %%
xgb = XGBRegressor()
parameters = {'nthread':[4], 
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07],
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}
xgb_grid = GridSearchCV(xgb, parameters, cv = 2, n_jobs = 5, verbose=True)
xgb_grid.fit(X_train, y)
y_pred = xgb_grid.predict(X_test)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  18 out of  18 | elapsed:   17.5s finished

# %%
submission = pd.DataFrame({ 'revenue' : y_pred })
submission.to_csv("my_submission16.csv", index=False)

# %% [markdown]
# # Using various methods

# %%
df = pd.read_csv("/content/drive/MyDrive/SUMMER ANALYTICS IITG/Hackathon/Train_Data.csv" , parse_dates=[0])
test  = pd.read_csv('/content/drive/MyDrive/SUMMER ANALYTICS IITG/Hackathon/Test_Data.csv' , parse_dates=[0])
uv=np.percentile(df.revenue,[99])[0]
df.revenue[(df.revenue>3*uv)]=3*uv

# %%
df1 = df.copy()
dfc = df1.append(test)

# %%
uv1=np.percentile(dfc.impressions,[99])[0]
dfc.impressions[(dfc.impressions>3*uv1)]=3*uv1
uv2=np.percentile(dfc.clicks,[99])[0]
dfc.clicks[(dfc.clicks>3*uv2)]=3*uv2
uv3=np.percentile(dfc.clicks,[99])[0]
dfc.clicks[(dfc.clicks>3*uv3)]=3*uv3
uv4=np.percentile(dfc.conversions,[99])[0]
dfc.conversions[(dfc.conversions>3*uv4)]=3*uv4

uv5=np.percentile(dfc.cost,[99])[0]
dfc.cost[(dfc.cost>3*uv5)]=3*uv5

# %%
dfc['weekday'] = dfc['date'].dt.weekday
dfc = dfc.drop(['date'], axis = 1)
dfc = dfc.drop(['campaign'] , axis = 1)
dfc['ci'] = dfc.clicks/dfc.impressions
dfc = dfc.drop(['clicks' , 'impressions'] , axis = 1)

# %%
dfc = dfc.drop(['ad'],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
Adgroup = LabelEncoder()
dfc['adgroup']=Adgroup.fit_transform(dfc["adgroup"])

# %%
X_train = dfc.iloc[:-318]
X_test = dfc.iloc[4571:]

# %%
X_test = X_test.drop(['revenue'] , axis = 1)
X_test.shape
# Out:
# (318, 5)

# %%
y = X_train['revenue']
X_train = X_train.drop(['revenue'] , axis = 1)
X_train.shape
# Out:
# (4571, 5)

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor
model = XGBRegressor()



parameters = {'nthread':[4], 
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], 
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}


xgb_grid = GridSearchCV(model,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)
xgb_grid.fit(X_train,y)
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y , xgb_grid.predict(X_train)))
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  18 out of  18 | elapsed:   15.4s finished
# 89.43345129461211

# %%
submission = pd.DataFrame({ 'revenue' : xgb_grid.predict(X_test) })
submission.to_csv("my_submission18.csv", index=False)
